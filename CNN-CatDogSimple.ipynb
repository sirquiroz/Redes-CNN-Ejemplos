# %% [markdown]
# https://medium.com/@jcrispis56/introducci%C3%B3n-al-deep-learning-parte-2-redes-neuronales-convolucionales-f743266d22a0

# %%
#https://www.floydhub.com/fastai/datasets/cats-vs-dogs/2
import os
#GetData
# !wget -U 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36' \
https://www.floydhub.com/api/v1/download/artifacts/data/VbpRSQnFkQmYaBUtwt3aca?is_dir=true&path=train -o /content/drive/My Drive/datasets

#borrar el archivo
os.remove('VbpRSQnFkQmYaBUtwt3aca?is_dir=true')
#comprobar las carpetas
print("lisatr carpetas")
os.listdir()
# Out:
# /bin/bash: -o: command not found
# --2020-08-21 05:52:00--  https://www.floydhub.com/api/v1/download/artifacts/data/VbpRSQnFkQmYaBUtwt3aca?is_dir=true
# Resolving www.floydhub.com (www.floydhub.com)... 104.26.0.30, 172.67.72.144, 104.26.1.30, ...
# Connecting to www.floydhub.com (www.floydhub.com)|104.26.0.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘VbpRSQnFkQmYaBUtwt3aca?is_dir=true’
#
# VbpRSQnFkQmYaBUtwt3     [      <=>           ] 845.69M  43.6MB/s    in 19s
#
# 2020-08-21 05:52:20 (43.5 MB/s) - ‘VbpRSQnFkQmYaBUtwt3aca?is_dir=true’ saved [886773760]
# ['.config', 'VbpRSQnFkQmYaBUtwt3aca?is_dir=true.1', 'drive', 'sample_data']

# %%
#descomprimir
import tarfile
tar = tarfile.open('VbpRSQnFkQmYaBUtwt3aca?is_dir=true.1',"r:*")

# %%
os.listdir()
# Out:
# ['.config', 'VbpRSQnFkQmYaBUtwt3aca?is_dir=true.1', 'drive', 'sample_data']

# %%
https://www.it-swarm.dev/es/python/extraer-google-drive-zip-de-google-colab-notebook/836953288/
